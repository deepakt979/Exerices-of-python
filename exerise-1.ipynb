# %%
print("hello"[4])
# Out:
# o

# %%
print(70 + float("23.43142"))
# Out:
# 93.43142

# %%
# 🚨 Don't change the code below 👇
two_digit_number = input("Type a two digit number: ")
# 🚨 Don't change the code above 👆

####################################
#Write your code below this line 👇
first_digit_number=(two_digit_number[0])

second_digit_number=(two_digit_number[1])

print(int(first_digit_number)+int(second_digit_number))
# Out:
# Type a two digit number: 32
# 5

# %%
print(round(8/3,2))
# Out:
# 2.67

# %%
score=0
height=4.5
winning=True

print(f"you score is {score},your height is {height},your winning is {winning}")
# Out:
# you score is 0,your height is 4.5,your winning is True
